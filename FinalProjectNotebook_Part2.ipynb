# %%
import json

with open("zip_dictionary.json","r") as open_file:
    data = json.load(open_file)

print(data['12202'])
# Out:
# {'1': 1800.0, '2': 1430.0, '3': 520.0, '4': 200.0, '5': 140.0, '6': 30.0, 'total': 4120.0, 'median_index': 2060.0, 'median_agi_stub': '2', 'Arthritis': {'Measure': 'Arthritis among adults aged >=18 years', 'Data_Value_Unit': '%', 'Data_Value_Type': 'Crude prevalence', 'Data_Value': '24.7'}, 'High_Blood_Pressure': {'Measure': 'High blood pressure among adults aged >=18 years', 'Data_Value_Unit': '%', 'Data_Value_Type': 'Crude prevalence', 'Data_Value': '36.7'}, 'Cancer': {'Measure': 'Cancer (excluding skin cancer) among adults aged >=18 years', 'Data_Value_Unit': '%', 'Data_Value_Type': 'Crude prevalence', 'Data_Value': '4.6'}, 'Asthma': {'Measure': 'Current asthma among adults aged >=18 years', 'Data_Value_Unit': '%', 'Data_Value_Type': 'Crude prevalence', 'Data_Value': '14.5'}, 'Heart_Disease': {'Measure': 'Coronary heart disease among adults aged >=18 years', 'Data_Value_Unit': '%', 'Data_Value_Type': 'Crude prevalence', 'Data_Value': '5.8'}, 'Pulmonary_Disease': {'Measure': 'Chron
# ...

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

arth_agi_1 = []
arth_agi_2 = []
arth_agi_3 = []
arth_agi_4 = []
arth_agi_5 = []
arth_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['Arthritis']['Measure'] == 'Arthritis among adults aged >=18 years' and data[zip_code]['Arthritis']['Data_Value_Unit'] == '%' and data[zip_code]['Arthritis']['Data_Value_Type'] == 'Crude prevalence':
        arthritis_perc = None
        try:
            arthritis_perc = float(data[zip_code]['Arthritis']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        arth_agi_1.append(arthritis_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['Arthritis']['Measure'] == 'Arthritis among adults aged >=18 years' and data[zip_code]['Arthritis']['Data_Value_Unit'] == '%' and data[zip_code]['Arthritis']['Data_Value_Type'] == 'Crude prevalence':
        arthritis_perc = None
        try:
            arthritis_perc = float(data[zip_code]['Arthritis']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        arth_agi_2.append(arthritis_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['Arthritis']['Measure'] == 'Arthritis among adults aged >=18 years' and data[zip_code]['Arthritis']['Data_Value_Unit'] == '%' and data[zip_code]['Arthritis']['Data_Value_Type'] == 'Crude prevalence':
        arthritis_perc = None
        try:
            arthritis_perc = float(data[zip_code]['Arthritis']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        arth_agi_3.append(arthritis_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['Arthritis']['Measure'] == 'Arthritis among adults aged >=18 years' and data[zip_code]['Arthritis']['Data_Value_Unit'] == '%' and data[zip_code]['Arthritis']['Data_Value_Type'] == 'Crude prevalence':
        arthritis_perc = None
        try:
            arthritis_perc = float(data[zip_code]['Arthritis']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        arth_agi_4.append(arthritis_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['Arthritis']['Measure'] == 'Arthritis among adults aged >=18 years' and data[zip_code]['Arthritis']['Data_Value_Unit'] == '%' and data[zip_code]['Arthritis']['Data_Value_Type'] == 'Crude prevalence':
        arthritis_perc = None
        try:
            arthritis_perc = float(data[zip_code]['Arthritis']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        arth_agi_5.append(arthritis_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['Arthritis']['Measure'] == 'Arthritis among adults aged >=18 years' and data[zip_code]['Arthritis']['Data_Value_Unit'] == '%' and data[zip_code]['Arthritis']['Data_Value_Type'] == 'Crude prevalence':
        arthritis_perc = None
        try:
            arthritis_perc = float(data[zip_code]['Arthritis']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        arth_agi_6.append(arthritis_perc)

print(len(arth_agi_1))
print(len(arth_agi_2))
print(len(arth_agi_3))
print(len(arth_agi_4))
print(len(arth_agi_5))
print(len(arth_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
arth_data = [arth_agi_1,arth_agi_2,arth_agi_3,arth_agi_4,arth_agi_5,arth_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'x-large'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(arth_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('Arthritis among adults aged >=18 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("arthritis_boxplot.jpg",bbox_inches='tight')
pyplot.show()

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

hbp_agi_1 = []
hbp_agi_2 = []
hbp_agi_3 = []
hbp_agi_4 = []
hbp_agi_5 = []
hbp_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['High_Blood_Pressure']['Measure'] == 'High blood pressure among adults aged >=18 years' and data[zip_code]['High_Blood_Pressure']['Data_Value_Unit'] == '%' and data[zip_code]['High_Blood_Pressure']['Data_Value_Type'] == 'Crude prevalence':
        hbp_perc = None
        try:
            hbp_perc = float(data[zip_code]['High_Blood_Pressure']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hbp_agi_1.append(hbp_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['High_Blood_Pressure']['Measure'] == 'High blood pressure among adults aged >=18 years' and data[zip_code]['High_Blood_Pressure']['Data_Value_Unit'] == '%' and data[zip_code]['High_Blood_Pressure']['Data_Value_Type'] == 'Crude prevalence':
        hbp_perc = None
        try:
            hbp_perc = float(data[zip_code]['High_Blood_Pressure']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hbp_agi_2.append(hbp_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['High_Blood_Pressure']['Measure'] == 'High blood pressure among adults aged >=18 years' and data[zip_code]['High_Blood_Pressure']['Data_Value_Unit'] == '%' and data[zip_code]['High_Blood_Pressure']['Data_Value_Type'] == 'Crude prevalence':
        hbp_perc = None
        try:
            hbp_perc = float(data[zip_code]['High_Blood_Pressure']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hbp_agi_3.append(hbp_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['High_Blood_Pressure']['Measure'] == 'High blood pressure among adults aged >=18 years' and data[zip_code]['High_Blood_Pressure']['Data_Value_Unit'] == '%' and data[zip_code]['High_Blood_Pressure']['Data_Value_Type'] == 'Crude prevalence':
        hbp_perc = None
        try:
            hbp_perc = float(data[zip_code]['High_Blood_Pressure']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hbp_agi_4.append(hbp_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['High_Blood_Pressure']['Measure'] == 'High blood pressure among adults aged >=18 years' and data[zip_code]['High_Blood_Pressure']['Data_Value_Unit'] == '%' and data[zip_code]['High_Blood_Pressure']['Data_Value_Type'] == 'Crude prevalence':
        hbp_perc = None
        try:
            hbp_perc = float(data[zip_code]['High_Blood_Pressure']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hbp_agi_5.append(hbp_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['High_Blood_Pressure']['Measure'] == 'High blood pressure among adults aged >=18 years' and data[zip_code]['High_Blood_Pressure']['Data_Value_Unit'] == '%' and data[zip_code]['High_Blood_Pressure']['Data_Value_Type'] == 'Crude prevalence':
        hbp_perc = None
        try:
            hbp_perc = float(data[zip_code]['High_Blood_Pressure']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hbp_agi_6.append(hbp_perc)

print(len(hbp_agi_1))
print(len(hbp_agi_2))
print(len(hbp_agi_3))
print(len(hbp_agi_4))
print(len(hbp_agi_5))
print(len(hbp_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
hbp_data = [hbp_agi_1,hbp_agi_2,hbp_agi_3,hbp_agi_4,hbp_agi_5,hbp_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'x-large'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(hbp_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('High blood pressure among adults aged >=18 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("high_blood_pressure_boxplot.jpg",bbox_inches='tight')
pyplot.show()

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

cancer_agi_1 = []
cancer_agi_2 = []
cancer_agi_3 = []
cancer_agi_4 = []
cancer_agi_5 = []
cancer_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['Cancer']['Measure'] == 'Cancer (excluding skin cancer) among adults aged >=18 years' and data[zip_code]['Cancer']['Data_Value_Unit'] == '%' and data[zip_code]['Cancer']['Data_Value_Type'] == 'Crude prevalence':
        cancer_perc = None
        try:
            cancer_perc = float(data[zip_code]['Cancer']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        cancer_agi_1.append(cancer_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['Cancer']['Measure'] == 'Cancer (excluding skin cancer) among adults aged >=18 years' and data[zip_code]['Cancer']['Data_Value_Unit'] == '%' and data[zip_code]['Cancer']['Data_Value_Type'] == 'Crude prevalence':
        cancer_perc = None
        try:
            cancer_perc = float(data[zip_code]['Cancer']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        cancer_agi_2.append(cancer_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['Cancer']['Measure'] == 'Cancer (excluding skin cancer) among adults aged >=18 years' and data[zip_code]['Cancer']['Data_Value_Unit'] == '%' and data[zip_code]['Cancer']['Data_Value_Type'] == 'Crude prevalence':
        cancer_perc = None
        try:
            cancer_perc = float(data[zip_code]['Cancer']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        cancer_agi_3.append(cancer_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['Cancer']['Measure'] == 'Cancer (excluding skin cancer) among adults aged >=18 years' and data[zip_code]['Cancer']['Data_Value_Unit'] == '%' and data[zip_code]['Cancer']['Data_Value_Type'] == 'Crude prevalence':
        cancer_perc = None
        try:
            cancer_perc = float(data[zip_code]['Cancer']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        cancer_agi_4.append(cancer_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['Cancer']['Measure'] == 'Cancer (excluding skin cancer) among adults aged >=18 years' and data[zip_code]['Cancer']['Data_Value_Unit'] == '%' and data[zip_code]['Cancer']['Data_Value_Type'] == 'Crude prevalence':
        cancer_perc = None
        try:
            cancer_perc = float(data[zip_code]['Cancer']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        cancer_agi_5.append(cancer_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['Cancer']['Measure'] == 'Cancer (excluding skin cancer) among adults aged >=18 years' and data[zip_code]['Cancer']['Data_Value_Unit'] == '%' and data[zip_code]['Cancer']['Data_Value_Type'] == 'Crude prevalence':
        cancer_perc = None
        try:
            cancer_perc = float(data[zip_code]['Cancer']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        cancer_agi_6.append(cancer_perc)

print(len(cancer_agi_1))
print(len(cancer_agi_2))
print(len(cancer_agi_3))
print(len(cancer_agi_4))
print(len(cancer_agi_5))
print(len(cancer_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
cancer_data = [cancer_agi_1,cancer_agi_2,cancer_agi_3,cancer_agi_4,cancer_agi_5,cancer_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'x-large'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(cancer_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('Cancer (excluding skin cancer) among adults aged >=18 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("cancer_boxplot.jpg",bbox_inches='tight')
pyplot.show()

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

asthma_agi_1 = []
asthma_agi_2 = []
asthma_agi_3 = []
asthma_agi_4 = []
asthma_agi_5 = []
asthma_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['Asthma']['Measure'] == 'Current asthma among adults aged >=18 years' and data[zip_code]['Asthma']['Data_Value_Unit'] == '%' and data[zip_code]['Asthma']['Data_Value_Type'] == 'Crude prevalence':
        asthma_perc = None
        try:
            asthma_perc = float(data[zip_code]['Asthma']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        asthma_agi_1.append(asthma_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['Asthma']['Measure'] == 'Current asthma among adults aged >=18 years' and data[zip_code]['Asthma']['Data_Value_Unit'] == '%' and data[zip_code]['Asthma']['Data_Value_Type'] == 'Crude prevalence':
        asthma_perc = None
        try:
            asthma_perc = float(data[zip_code]['Asthma']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        asthma_agi_2.append(asthma_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['Asthma']['Measure'] == 'Current asthma among adults aged >=18 years' and data[zip_code]['Asthma']['Data_Value_Unit'] == '%' and data[zip_code]['Asthma']['Data_Value_Type'] == 'Crude prevalence':
        asthma_perc = None
        try:
            asthma_perc = float(data[zip_code]['Asthma']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        asthma_agi_3.append(asthma_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['Asthma']['Measure'] == 'Current asthma among adults aged >=18 years' and data[zip_code]['Asthma']['Data_Value_Unit'] == '%' and data[zip_code]['Asthma']['Data_Value_Type'] == 'Crude prevalence':
        asthma_perc = None
        try:
            asthma_perc = float(data[zip_code]['Asthma']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        asthma_agi_4.append(asthma_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['Asthma']['Measure'] == 'Current asthma among adults aged >=18 years' and data[zip_code]['Asthma']['Data_Value_Unit'] == '%' and data[zip_code]['Asthma']['Data_Value_Type'] == 'Crude prevalence':
        asthma_perc = None
        try:
            asthma_perc = float(data[zip_code]['Asthma']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        asthma_agi_5.append(asthma_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['Asthma']['Measure'] == 'Current asthma among adults aged >=18 years' and data[zip_code]['Asthma']['Data_Value_Unit'] == '%' and data[zip_code]['Asthma']['Data_Value_Type'] == 'Crude prevalence':
        asthma_perc = None
        try:
            asthma_perc = float(data[zip_code]['Asthma']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        asthma_agi_6.append(asthma_perc)

print(len(cancer_agi_1))
print(len(cancer_agi_2))
print(len(cancer_agi_3))
print(len(cancer_agi_4))
print(len(cancer_agi_5))
print(len(cancer_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
asthma_data = [asthma_agi_1,asthma_agi_2,asthma_agi_3,asthma_agi_4,asthma_agi_5,asthma_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'x-large'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(asthma_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('Current asthma among adults aged >=18 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("asthma_boxplot.jpg",bbox_inches='tight')
pyplot.show()

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

hd_agi_1 = []
hd_agi_2 = []
hd_agi_3 = []
hd_agi_4 = []
hd_agi_5 = []
hd_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['Heart_Disease']['Measure'] == 'Coronary heart disease among adults aged >=18 years' and data[zip_code]['Heart_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Heart_Disease']['Data_Value_Type'] == 'Crude prevalence':
        hd_perc = None
        try:
            hd_perc = float(data[zip_code]['Heart_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hd_agi_1.append(hd_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['Heart_Disease']['Measure'] == 'Coronary heart disease among adults aged >=18 years' and data[zip_code]['Heart_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Heart_Disease']['Data_Value_Type'] == 'Crude prevalence':
        hd_perc = None
        try:
            hd_perc = float(data[zip_code]['Heart_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hd_agi_2.append(hd_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['Heart_Disease']['Measure'] == 'Coronary heart disease among adults aged >=18 years' and data[zip_code]['Heart_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Heart_Disease']['Data_Value_Type'] == 'Crude prevalence':
        hd_perc = None
        try:
            hd_perc = float(data[zip_code]['Heart_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hd_agi_3.append(hd_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['Heart_Disease']['Measure'] == 'Coronary heart disease among adults aged >=18 years' and data[zip_code]['Heart_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Heart_Disease']['Data_Value_Type'] == 'Crude prevalence':
        hd_perc = None
        try:
            hd_perc = float(data[zip_code]['Heart_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hd_agi_4.append(hd_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['Heart_Disease']['Measure'] == 'Coronary heart disease among adults aged >=18 years' and data[zip_code]['Heart_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Heart_Disease']['Data_Value_Type'] == 'Crude prevalence':
        hd_perc = None
        try:
            hd_perc = float(data[zip_code]['Heart_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hd_agi_5.append(hd_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['Heart_Disease']['Measure'] == 'Coronary heart disease among adults aged >=18 years' and data[zip_code]['Heart_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Heart_Disease']['Data_Value_Type'] == 'Crude prevalence':
        hd_perc = None
        try:
            hd_perc = float(data[zip_code]['Heart_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hd_agi_6.append(hd_perc)

print(len(hd_agi_1))
print(len(hd_agi_2))
print(len(hd_agi_3))
print(len(hd_agi_4))
print(len(hd_agi_5))
print(len(hd_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
hd_data = [hd_agi_1,hd_agi_2,hd_agi_3,hd_agi_4,hd_agi_5,hd_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'x-large'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(hd_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('Coronary heart disease among adults aged >=18 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("heart_disease_boxplot.jpg",bbox_inches='tight')
pyplot.show()

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

pulm_agi_1 = []
pulm_agi_2 = []
pulm_agi_3 = []
pulm_agi_4 = []
pulm_agi_5 = []
pulm_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['Pulmonary_Disease']['Measure'] == 'Chronic obstructive pulmonary disease among adults aged >=18 years' and data[zip_code]['Pulmonary_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Pulmonary_Disease']['Data_Value_Type'] == 'Crude prevalence':
        pulm_perc = None
        try:
            pulm_perc = float(data[zip_code]['Pulmonary_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        pulm_agi_1.append(pulm_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['Pulmonary_Disease']['Measure'] == 'Chronic obstructive pulmonary disease among adults aged >=18 years' and data[zip_code]['Pulmonary_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Pulmonary_Disease']['Data_Value_Type'] == 'Crude prevalence':
        pulm_perc = None
        try:
            pulm_perc = float(data[zip_code]['Pulmonary_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        pulm_agi_2.append(pulm_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['Pulmonary_Disease']['Measure'] == 'Chronic obstructive pulmonary disease among adults aged >=18 years' and data[zip_code]['Pulmonary_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Pulmonary_Disease']['Data_Value_Type'] == 'Crude prevalence':
        pulm_perc = None
        try:
            pulm_perc = float(data[zip_code]['Pulmonary_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        pulm_agi_3.append(pulm_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['Pulmonary_Disease']['Measure'] == 'Chronic obstructive pulmonary disease among adults aged >=18 years' and data[zip_code]['Pulmonary_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Pulmonary_Disease']['Data_Value_Type'] == 'Crude prevalence':
        pulm_perc = None
        try:
            pulm_perc = float(data[zip_code]['Pulmonary_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        pulm_agi_4.append(pulm_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['Pulmonary_Disease']['Measure'] == 'Chronic obstructive pulmonary disease among adults aged >=18 years' and data[zip_code]['Pulmonary_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Pulmonary_Disease']['Data_Value_Type'] == 'Crude prevalence':
        pulm_perc = None
        try:
            pulm_perc = float(data[zip_code]['Pulmonary_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        pulm_agi_5.append(pulm_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['Pulmonary_Disease']['Measure'] == 'Chronic obstructive pulmonary disease among adults aged >=18 years' and data[zip_code]['Pulmonary_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Pulmonary_Disease']['Data_Value_Type'] == 'Crude prevalence':
        pulm_perc = None
        try:
            pulm_perc = float(data[zip_code]['Pulmonary_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        pulm_agi_6.append(pulm_perc)

print(len(pulm_agi_1))
print(len(pulm_agi_2))
print(len(pulm_agi_3))
print(len(pulm_agi_4))
print(len(pulm_agi_5))
print(len(pulm_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
pulm_data = [pulm_agi_1,pulm_agi_2,pulm_agi_3,pulm_agi_4,pulm_agi_5,pulm_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'x-large'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(pulm_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('Chronic obstructive pulmonary disease among adults aged >=18 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("pulmonary_disease_boxplot.jpg",bbox_inches='tight')
pyplot.show()

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

dep_agi_1 = []
dep_agi_2 = []
dep_agi_3 = []
dep_agi_4 = []
dep_agi_5 = []
dep_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['Depression']['Measure'] == 'Depression among adults aged >=18 years' and data[zip_code]['Depression']['Data_Value_Unit'] == '%' and data[zip_code]['Depression']['Data_Value_Type'] == 'Crude prevalence':
        dep_perc = None
        try:
            dep_perc = float(data[zip_code]['Depression']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        dep_agi_1.append(dep_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['Depression']['Measure'] == 'Depression among adults aged >=18 years' and data[zip_code]['Depression']['Data_Value_Unit'] == '%' and data[zip_code]['Depression']['Data_Value_Type'] == 'Crude prevalence':
        dep_perc = None
        try:
            dep_perc = float(data[zip_code]['Depression']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        dep_agi_2.append(dep_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['Depression']['Measure'] == 'Depression among adults aged >=18 years' and data[zip_code]['Depression']['Data_Value_Unit'] == '%' and data[zip_code]['Depression']['Data_Value_Type'] == 'Crude prevalence':
        dep_perc = None
        try:
            dep_perc = float(data[zip_code]['Depression']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        dep_agi_3.append(dep_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['Depression']['Measure'] == 'Depression among adults aged >=18 years' and data[zip_code]['Depression']['Data_Value_Unit'] == '%' and data[zip_code]['Depression']['Data_Value_Type'] == 'Crude prevalence':
        dep_perc = None
        try:
            dep_perc = float(data[zip_code]['Depression']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        dep_agi_4.append(dep_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['Depression']['Measure'] == 'Depression among adults aged >=18 years' and data[zip_code]['Depression']['Data_Value_Unit'] == '%' and data[zip_code]['Depression']['Data_Value_Type'] == 'Crude prevalence':
        dep_perc = None
        try:
            dep_perc = float(data[zip_code]['Depression']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        dep_agi_5.append(dep_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['Depression']['Measure'] == 'Depression among adults aged >=18 years' and data[zip_code]['Depression']['Data_Value_Unit'] == '%' and data[zip_code]['Depression']['Data_Value_Type'] == 'Crude prevalence':
        dep_perc = None
        try:
            dep_perc = float(data[zip_code]['Depression']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        dep_agi_6.append(dep_perc)

print(len(dep_agi_1))
print(len(dep_agi_2))
print(len(dep_agi_3))
print(len(dep_agi_4))
print(len(dep_agi_5))
print(len(dep_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
dep_data = [dep_agi_1,dep_agi_2,dep_agi_3,dep_agi_4,dep_agi_5,dep_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'x-large'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(dep_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('Depression among adults aged >=18 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("depression_boxplot.jpg",bbox_inches='tight')
pyplot.show()

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

diab_agi_1 = []
diab_agi_2 = []
diab_agi_3 = []
diab_agi_4 = []
diab_agi_5 = []
diab_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['Diabetes']['Measure'] == 'Diagnosed diabetes among adults aged >=18 years' and data[zip_code]['Diabetes']['Data_Value_Unit'] == '%' and data[zip_code]['Diabetes']['Data_Value_Type'] == 'Crude prevalence':
        diab_perc = None
        try:
            diab_perc = float(data[zip_code]['Diabetes']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        diab_agi_1.append(diab_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['Diabetes']['Measure'] == 'Diagnosed diabetes among adults aged >=18 years' and data[zip_code]['Diabetes']['Data_Value_Unit'] == '%' and data[zip_code]['Diabetes']['Data_Value_Type'] == 'Crude prevalence':
        diab_perc = None
        try:
            diab_perc = float(data[zip_code]['Diabetes']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        diab_agi_2.append(diab_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['Diabetes']['Measure'] == 'Diagnosed diabetes among adults aged >=18 years' and data[zip_code]['Diabetes']['Data_Value_Unit'] == '%' and data[zip_code]['Diabetes']['Data_Value_Type'] == 'Crude prevalence':
        diab_perc = None
        try:
            diab_perc = float(data[zip_code]['Diabetes']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        diab_agi_3.append(diab_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['Diabetes']['Measure'] == 'Diagnosed diabetes among adults aged >=18 years' and data[zip_code]['Diabetes']['Data_Value_Unit'] == '%' and data[zip_code]['Diabetes']['Data_Value_Type'] == 'Crude prevalence':
        diab_perc = None
        try:
            diab_perc = float(data[zip_code]['Diabetes']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        diab_agi_4.append(diab_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['Diabetes']['Measure'] == 'Diagnosed diabetes among adults aged >=18 years' and data[zip_code]['Diabetes']['Data_Value_Unit'] == '%' and data[zip_code]['Diabetes']['Data_Value_Type'] == 'Crude prevalence':
        diab_perc = None
        try:
            diab_perc = float(data[zip_code]['Diabetes']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        diab_agi_5.append(diab_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['Diabetes']['Measure'] == 'Diagnosed diabetes among adults aged >=18 years' and data[zip_code]['Diabetes']['Data_Value_Unit'] == '%' and data[zip_code]['Diabetes']['Data_Value_Type'] == 'Crude prevalence':
        diab_perc = None
        try:
            diab_perc = float(data[zip_code]['Diabetes']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        diab_agi_6.append(diab_perc)

print(len(dep_agi_1))
print(len(dep_agi_2))
print(len(dep_agi_3))
print(len(dep_agi_4))
print(len(dep_agi_5))
print(len(dep_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
diab_data = [diab_agi_1,diab_agi_2,diab_agi_3,diab_agi_4,diab_agi_5,diab_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'x-large'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(diab_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('Diagnosed diabetes among adults aged >=18 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("diabetes_boxplot.jpg",bbox_inches='tight')
pyplot.show()

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

hc_agi_1 = []
hc_agi_2 = []
hc_agi_3 = []
hc_agi_4 = []
hc_agi_5 = []
hc_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['High_Cholesterol']['Measure'] == 'High cholesterol among adults aged >=18 years who have been screened in the past 5 years' and data[zip_code]['High_Cholesterol']['Data_Value_Unit'] == '%' and data[zip_code]['High_Cholesterol']['Data_Value_Type'] == 'Crude prevalence':
        hc_perc = None
        try:
            hc_perc = float(data[zip_code]['High_Cholesterol']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hc_agi_1.append(hc_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['High_Cholesterol']['Measure'] == 'High cholesterol among adults aged >=18 years who have been screened in the past 5 years' and data[zip_code]['High_Cholesterol']['Data_Value_Unit'] == '%' and data[zip_code]['High_Cholesterol']['Data_Value_Type'] == 'Crude prevalence':
        hc_perc = None
        try:
            hc_perc = float(data[zip_code]['High_Cholesterol']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hc_agi_2.append(hc_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['High_Cholesterol']['Measure'] == 'High cholesterol among adults aged >=18 years who have been screened in the past 5 years' and data[zip_code]['High_Cholesterol']['Data_Value_Unit'] == '%' and data[zip_code]['High_Cholesterol']['Data_Value_Type'] == 'Crude prevalence':
        hc_perc = None
        try:
            hc_perc = float(data[zip_code]['High_Cholesterol']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hc_agi_3.append(hc_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['High_Cholesterol']['Measure'] == 'High cholesterol among adults aged >=18 years who have been screened in the past 5 years' and data[zip_code]['High_Cholesterol']['Data_Value_Unit'] == '%' and data[zip_code]['High_Cholesterol']['Data_Value_Type'] == 'Crude prevalence':
        hc_perc = None
        try:
            hc_perc = float(data[zip_code]['High_Cholesterol']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hc_agi_4.append(hc_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['High_Cholesterol']['Measure'] == 'High cholesterol among adults aged >=18 years who have been screened in the past 5 years' and data[zip_code]['High_Cholesterol']['Data_Value_Unit'] == '%' and data[zip_code]['High_Cholesterol']['Data_Value_Type'] == 'Crude prevalence':
        hc_perc = None
        try:
            hc_perc = float(data[zip_code]['High_Cholesterol']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hc_agi_5.append(hc_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['High_Cholesterol']['Measure'] == 'High cholesterol among adults aged >=18 years who have been screened in the past 5 years' and data[zip_code]['High_Cholesterol']['Data_Value_Unit'] == '%' and data[zip_code]['High_Cholesterol']['Data_Value_Type'] == 'Crude prevalence':
        hc_perc = None
        try:
            hc_perc = float(data[zip_code]['High_Cholesterol']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        hc_agi_6.append(hc_perc)

print(len(hc_agi_1))
print(len(hc_agi_2))
print(len(hc_agi_3))
print(len(hc_agi_4))
print(len(hc_agi_5))
print(len(hc_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
hc_data = [hc_agi_1,hc_agi_2,hc_agi_3,hc_agi_4,hc_agi_5,hc_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'medium'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(hc_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('High cholesterol among adults aged >=18 years who have been screened in the past 5 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("high_cholesterol_boxplot.jpg",bbox_inches='tight')
pyplot.show()

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

kd_agi_1 = []
kd_agi_2 = []
kd_agi_3 = []
kd_agi_4 = []
kd_agi_5 = []
kd_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['Kidney_Disease']['Measure'] == 'Chronic kidney disease among adults aged >=18 years' and data[zip_code]['Kidney_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Kidney_Disease']['Data_Value_Type'] == 'Crude prevalence':
        kd_perc = None
        try:
            kd_perc = float(data[zip_code]['Kidney_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        kd_agi_1.append(kd_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['Kidney_Disease']['Measure'] == 'Chronic kidney disease among adults aged >=18 years' and data[zip_code]['Kidney_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Kidney_Disease']['Data_Value_Type'] == 'Crude prevalence':
        kd_perc = None
        try:
            kd_perc = float(data[zip_code]['Kidney_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        kd_agi_2.append(kd_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['Kidney_Disease']['Measure'] == 'Chronic kidney disease among adults aged >=18 years' and data[zip_code]['Kidney_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Kidney_Disease']['Data_Value_Type'] == 'Crude prevalence':
        kd_perc = None
        try:
            kd_perc = float(data[zip_code]['Kidney_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        kd_agi_3.append(kd_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['Kidney_Disease']['Measure'] == 'Chronic kidney disease among adults aged >=18 years' and data[zip_code]['Kidney_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Kidney_Disease']['Data_Value_Type'] == 'Crude prevalence':
        kd_perc = None
        try:
            kd_perc = float(data[zip_code]['Kidney_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        kd_agi_4.append(kd_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['Kidney_Disease']['Measure'] == 'Chronic kidney disease among adults aged >=18 years' and data[zip_code]['Kidney_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Kidney_Disease']['Data_Value_Type'] == 'Crude prevalence':
        kd_perc = None
        try:
            kd_perc = float(data[zip_code]['Kidney_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        kd_agi_5.append(kd_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['Kidney_Disease']['Measure'] == 'Chronic kidney disease among adults aged >=18 years' and data[zip_code]['Kidney_Disease']['Data_Value_Unit'] == '%' and data[zip_code]['Kidney_Disease']['Data_Value_Type'] == 'Crude prevalence':
        kd_perc = None
        try:
            kd_perc = float(data[zip_code]['Kidney_Disease']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        kd_agi_6.append(kd_perc)

print(len(hc_agi_1))
print(len(hc_agi_2))
print(len(hc_agi_3))
print(len(hc_agi_4))
print(len(hc_agi_5))
print(len(hc_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
kd_data = [kd_agi_1,kd_agi_2,kd_agi_3,kd_agi_4,kd_agi_5,kd_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'x-large'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(kd_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('Chronic kidney disease among adults aged >=18 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("kidney_disease_boxplot.jpg",bbox_inches='tight')
pyplot.show()

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

obe_agi_1 = []
obe_agi_2 = []
obe_agi_3 = []
obe_agi_4 = []
obe_agi_5 = []
obe_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['Obesity']['Measure'] == 'Obesity among adults aged >=18 years' and data[zip_code]['Obesity']['Data_Value_Unit'] == '%' and data[zip_code]['Obesity']['Data_Value_Type'] == 'Crude prevalence':
        obe_perc = None
        try:
            obe_perc = float(data[zip_code]['Obesity']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        obe_agi_1.append(obe_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['Obesity']['Measure'] == 'Obesity among adults aged >=18 years' and data[zip_code]['Obesity']['Data_Value_Unit'] == '%' and data[zip_code]['Obesity']['Data_Value_Type'] == 'Crude prevalence':
        obe_perc = None
        try:
            obe_perc = float(data[zip_code]['Obesity']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        obe_agi_2.append(obe_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['Obesity']['Measure'] == 'Obesity among adults aged >=18 years' and data[zip_code]['Obesity']['Data_Value_Unit'] == '%' and data[zip_code]['Obesity']['Data_Value_Type'] == 'Crude prevalence':
        obe_perc = None
        try:
            obe_perc = float(data[zip_code]['Obesity']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        obe_agi_3.append(obe_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['Obesity']['Measure'] == 'Obesity among adults aged >=18 years' and data[zip_code]['Obesity']['Data_Value_Unit'] == '%' and data[zip_code]['Obesity']['Data_Value_Type'] == 'Crude prevalence':
        obe_perc = None
        try:
            obe_perc = float(data[zip_code]['Obesity']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        obe_agi_4.append(obe_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['Obesity']['Measure'] == 'Obesity among adults aged >=18 years' and data[zip_code]['Obesity']['Data_Value_Unit'] == '%' and data[zip_code]['Obesity']['Data_Value_Type'] == 'Crude prevalence':
        obe_perc = None
        try:
            obe_perc = float(data[zip_code]['Obesity']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        obe_agi_5.append(obe_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['Obesity']['Measure'] == 'Obesity among adults aged >=18 years' and data[zip_code]['Obesity']['Data_Value_Unit'] == '%' and data[zip_code]['Obesity']['Data_Value_Type'] == 'Crude prevalence':
        obe_perc = None
        try:
            obe_perc = float(data[zip_code]['Obesity']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        obe_agi_6.append(obe_perc)

print(len(obe_agi_1))
print(len(obe_agi_2))
print(len(obe_agi_3))
print(len(obe_agi_4))
print(len(obe_agi_5))
print(len(obe_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
obe_data = [obe_agi_1,obe_agi_2,obe_agi_3,obe_agi_4,obe_agi_5,obe_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'x-large'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(obe_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('Obesity among adults aged >=18 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("obesity_boxplot.jpg",bbox_inches='tight')
pyplot.show()

# %%
# Now that we have our data stored on disk, we can start to make some visualizations.
from matplotlib import pyplot

strk_agi_1 = []
strk_agi_2 = []
strk_agi_3 = []
strk_agi_4 = []
strk_agi_5 = []
strk_agi_6 = []

for zip_code in data:
    if data[zip_code]['median_agi_stub'] == '1' and data[zip_code]['Stroke']['Measure'] == 'Stroke among adults aged >=18 years' and data[zip_code]['Stroke']['Data_Value_Unit'] == '%' and data[zip_code]['Stroke']['Data_Value_Type'] == 'Crude prevalence':
        strk_perc = None
        try:
            strk_perc = float(data[zip_code]['Stroke']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        strk_agi_1.append(strk_perc)
    if data[zip_code]['median_agi_stub'] == '2' and data[zip_code]['Stroke']['Measure'] == 'Stroke among adults aged >=18 years' and data[zip_code]['Stroke']['Data_Value_Unit'] == '%' and data[zip_code]['Stroke']['Data_Value_Type'] == 'Crude prevalence':
        strk_perc = None
        try:
            strk_perc = float(data[zip_code]['Stroke']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        strk_agi_2.append(strk_perc)
    if data[zip_code]['median_agi_stub'] == '3' and data[zip_code]['Stroke']['Measure'] == 'Stroke among adults aged >=18 years' and data[zip_code]['Stroke']['Data_Value_Unit'] == '%' and data[zip_code]['Stroke']['Data_Value_Type'] == 'Crude prevalence':
        strk_perc = None
        try:
            strk_perc = float(data[zip_code]['Stroke']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        strk_agi_3.append(strk_perc)
    if data[zip_code]['median_agi_stub'] == '4' and data[zip_code]['Stroke']['Measure'] == 'Stroke among adults aged >=18 years' and data[zip_code]['Stroke']['Data_Value_Unit'] == '%' and data[zip_code]['Stroke']['Data_Value_Type'] == 'Crude prevalence':
        strk_perc = None
        try:
            strk_perc = float(data[zip_code]['Stroke']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        strk_agi_4.append(strk_perc)
    if data[zip_code]['median_agi_stub'] == '5' and data[zip_code]['Stroke']['Measure'] == 'Stroke among adults aged >=18 years' and data[zip_code]['Stroke']['Data_Value_Unit'] == '%' and data[zip_code]['Stroke']['Data_Value_Type'] == 'Crude prevalence':
        strk_perc = None
        try:
            strk_perc = float(data[zip_code]['Stroke']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        strk_agi_5.append(strk_perc)
    if data[zip_code]['median_agi_stub'] == '6' and data[zip_code]['Stroke']['Measure'] == 'Stroke among adults aged >=18 years' and data[zip_code]['Stroke']['Data_Value_Unit'] == '%' and data[zip_code]['Stroke']['Data_Value_Type'] == 'Crude prevalence':
        strk_perc = None
        try:
            strk_perc = float(data[zip_code]['Stroke']['Data_Value'])
        except Exception as e:
            print(str(zip_code) + str(e))
            continue
        strk_agi_6.append(strk_perc)

print(len(strk_agi_1))
print(len(strk_agi_2))
print(len(strk_agi_3))
print(len(strk_agi_4))
print(len(strk_agi_5))
print(len(strk_agi_6))
# Out:
# 487
# 17408
# 6945
# 1235
# 588
# 14

# %%
# Removing outliers to get a clearer boxplot for each median_agi_stub category.
from matplotlib import pyplot

# Create dataframe
strk_data = [strk_agi_1,strk_agi_2,strk_agi_3,strk_agi_4,strk_agi_5,strk_agi_6]

# Plot the dataframe
fontdict_title = {'family':'serif','variant':'small-caps','weight':'medium','size':'x-large'}
fontdict_label = {'family':'serif','variant':'small-caps','weight':'light','size':'small'}
fontdict_ticks = {'family':'serif','variant':'small-caps','weight':'light','size':'x-small'}
pyplot.boxplot(strk_data,showfliers=False)
pyplot.xticks([1,2,3,4,5,6],['\$1-\$24,999','\$25,000-\$49,999','\$50,000-\$74,999','\$75,000-\$99,999','\$100,000-\$199,999','\$200,000 or more'],rotation=60,fontdict=fontdict_ticks)
pyplot.title('Stroke among adults aged >=18 years',fontdict=fontdict_title)
pyplot.xlabel('Median Adjusted Gross Income (AGI) Category',fontdict=fontdict_label)
pyplot.ylabel('Crude Prevalence (%)',fontdict=fontdict_label)

# Display the plot
pyplot.savefig("obesity_boxplot.jpg",bbox_inches='tight')
pyplot.show()
